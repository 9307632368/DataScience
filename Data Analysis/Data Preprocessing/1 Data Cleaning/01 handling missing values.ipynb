# %% [markdown]
# 1 handling missing values

# %%
import pandas as pd
import numpy as np

# %%
# loading dataset
data=pd.read_csv('C:/Users/polro/06 data preprocessing/datasets/titanic.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# methods to handle missing values

# %%
# checking missing values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
missing_ratio=data.isnull().mean()
cols_to_drop=missing_ratio[missing_ratio>0.1].index
cols_to_drop
# Out:
# Index(['Age', 'Cabin'], dtype='object')

# %%
from scify.stats import skewfrom scify.stats import skew
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30824\3641522100.py in <module>
# ----> 1 from scify.stats import skew
#
# ModuleNotFoundError: No module named 'scify'

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
# 1)remove missing values
#data.dropna(inplace=True)# remove the rows with any missing values

# %%
# 2)filling the missing values(imputation)

# a) fill numeric columns with mean
data['Fare'].fillna(data['Fare'].mean(),inplace=True)

# b) fill categorical column with mode
data['Cabin'].fillna(data['Cabin'].mode(),inplace=True)

# c) forward fill 
data['Age'].fillna(data['Age'].ffill(),inplace=True)

# d) backward fill
data['Age'].fillna(data['Age'].bfill(),inplace=True)

# %%
# revisig the concepts

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:/Users/polro/06 data preprocessing/datasets/titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# checking null values
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.columns.value_counts().sum()
# Out:
# 12

# %%
data.isnull().mean()
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.205742
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.002392
# Cabin          0.782297
# Embarked       0.000000
# dtype: float64

# %%
# remove null values
data.dropna(inplace=True)

# %%
data.dropna[[data.isnull().mean()>0.5,axis=1]]
# Out:
#   File "C:\Users\polro\AppData\Local\Temp\ipykernel_23808\1530711096.py", line 1
#     data.dropna[[data.isnull().mean()>0.5,axis=1]]
#                                               ^
# SyntaxError: invalid syntax

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.columns.value_counts().sum()
# Out:
# 12

# %%
data.drop(columns='Age',inplace=True)

# %%
data.columns.value_counts().sum()
# Out:
# 11

# %%
data.isnull().mean()
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Cabin          0.0
# Embarked       0.0
# dtype: float64

# %%
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId   Survived     Pclass      SibSp      Parch        Fare
# count    87.000000  87.000000  87.000000  87.000000  87.000000   87.000000
# mean   1102.712644   0.505747   1.137931   0.597701   0.482759   98.109198
# std     126.751901   0.502865   0.435954   0.637214   0.860801   88.177319
# min     904.000000   0.000000   1.000000   0.000000   0.000000    0.000000
# 25%     986.000000   0.000000   1.000000   0.000000   0.000000   35.339600
# 50%    1094.000000   1.000000   1.000000   1.000000   0.000000   71.283300
# 75%    1216.000000   1.000000   1.000000   1.000000   1.000000  135.066650
# max    1306.000000   1.000000   3.000000   3.000000   4.000000  512.329200

# %%
data.columns.value_counts().sum()
# Out:
# 11

# %%
data['Sex'].value_counts()
# Out:
# female    44
# male      43
# Name: Sex, dtype: int64

# %%
data=pd.read_csv('C:/Users/polro/06 data preprocessing/datasets/titanic.csv')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
for columns in data:
    if data[columns].dtype == 'float64':
        data[columns].fillna(data[columns].mean(),inplace=True)
    elif data[columns].dtype == 'object':
        data[columns].fillna(data[columns].mode(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          326
# Embarked         0
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean())
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
data['Cabin'].dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          418 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         418 non-null    float64
#  10  Cabin        92 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
