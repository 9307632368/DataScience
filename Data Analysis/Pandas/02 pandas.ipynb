# %%
import pandas as pd

# %%
dff=pd.read_csv("heart.csv")

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dff.shape
# Out:
# (303, 14)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# are all columns are visible in dataframe

# %%
pd.set_option('display.max_columns',14)

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
pd.set_option('display.max_rows',16)

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df=pd.read_csv('o2Saturation.csv')

# %%
df
# Out:
#       98.6
# 0     98.6
# 1     98.6
# 2     98.6
# 3     98.1
# 4     97.5
# ...    ...
# 3580  98.6
# 3581  98.6
# 3582  98.6
# 3583  98.6
# 3584  98.6
#
# [3585 rows x 1 columns]

# %%
pd.set_option('display.max_rows',64)

# %%
# first five columns
df.head()
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5

# %%
#first 10 rows
df.head(10)
# Out:
#    98.6
# 0  98.6
# 1  98.6
# 2  98.6
# 3  98.1
# 4  97.5
# 5  97.5
# 6  97.5
# 7  97.5
# 8  97.5
# 9  97.5

# %%
# last five columns
df.tail()
# Out:
#       98.6
# 3580  98.6
# 3581  98.6
# 3582  98.6
# 3583  98.6
# 3584  98.6

# %%
df.tail(20)
# Out:
#       98.6
# 3565  98.6
# 3566  98.6
# 3567  98.6
# 3568  99.3
# 3569  99.6
# 3570  98.8
# 3571  99.3
# 3572  98.8
# 3573  99.3
# 3574  99.6
# 3575  99.6
# 3576  98.8
# 3577  98.6
# 3578  98.6
# 3579  98.6
# 3580  98.6
# 3581  98.6
# 3582  98.6
# 3583  98.6
# 3584  98.6

# %%
people={"name":"Rohan","last":"pol","email":"polrohan10@gmail.com"}
people
# Out:
# {'name': 'Rohan', 'last': 'pol', 'email': 'polrohan10@gmail.com'}

# %%
people={"name":["rohan","bablu","husen","mahesh"],
        "last":["pol","pol","shaikh","jadhav"],
        "email":["polrohan10@gmail.com","poldhananjay20@gmil.com","husen@gmial.com","mahesh@gmail.com"]
       }
people
# Out:
# {'name': ['rohan', 'bablu', 'husen', 'mahesh'],
#  'last': ['pol', 'pol', 'shaikh', 'jadhav'],
#  'email': ['polrohan10@gmail.com',
#   'poldhananjay20@gmil.com',
#   'husen@gmial.com',
#   'mahesh@gmail.com']}

# %%
# dictionary converted into dataframe
df=pd.DataFrame(people)
df
# Out:
#      name    last                    email
# 0   rohan     pol     polrohan10@gmail.com
# 1   bablu     pol  poldhananjay20@gmil.com
# 2   husen  shaikh          husen@gmial.com
# 3  mahesh  jadhav         mahesh@gmail.com

# %%
df.head()
# Out:
#      name    last                    email
# 0   rohan     pol     polrohan10@gmail.com
# 1   bablu     pol  poldhananjay20@gmil.com
# 2   husen  shaikh          husen@gmial.com
# 3  mahesh  jadhav         mahesh@gmail.com

# %%
# series -row of single column
# dataframe- container for multiple series
df["email"]
# Out:
# 0       polrohan10@gmail.com
# 1    poldhananjay20@gmil.com
# 2            husen@gmial.com
# 3           mahesh@gmail.com
# Name: email, dtype: object

# %%
type(df["email"])
# Out:
# pandas.core.series.Series

# %%
# acess multiple values
df[["name","last"]]
# Out:
#      name    last
# 0   rohan     pol
# 1   bablu     pol
# 2   husen  shaikh
# 3  mahesh  jadhav

# %%
type(df[["name","last"]])
# Out:
# pandas.core.frame.DataFrame

# %%
#acess all columns of dataframe
df.columns
# Out:
# Index(['name', 'last', 'email'], dtype='object')

# %%
# loc label based
# iloc integer position based
df.iloc[0]
# Out:
# name                    rohan
# last                      pol
# email    polrohan10@gmail.com
# Name: 0, dtype: object

# %%
# acess two rows
df.iloc[[0,1]]
# Out:
#     name last                    email
# 0  rohan  pol     polrohan10@gmail.com
# 1  bablu  pol  poldhananjay20@gmil.com

# %%
df.head(2)
# Out:
#     name last                    email
# 0  rohan  pol     polrohan10@gmail.com
# 1  bablu  pol  poldhananjay20@gmil.com

# %% [markdown]
# # Rows of specific column only

# %%
df.iloc[[0,1],2]
# Out:
# 0       polrohan10@gmail.com
# 1    poldhananjay20@gmil.com
# Name: email, dtype: object

# %%
df.iloc[[1,2],[0,1]]
# Out:
#     name    last
# 1  bablu     pol
# 2  husen  shaikh

# %% [markdown]
# acess using loc

# %%
df.loc[0]
# Out:
# name                    rohan
# last                      pol
# email    polrohan10@gmail.com
# Name: 0, dtype: object

# %%
df.loc[[1,2]]
# Out:
#     name    last                    email
# 1  bablu     pol  poldhananjay20@gmil.com
# 2  husen  shaikh          husen@gmial.com

# %%
df.loc[[1,2],'name']
# Out:
# 1    bablu
# 2    husen
# Name: name, dtype: object

# %%
df.loc[[0,1],["name","last"]]
# Out:
#     name last
# 0  rohan  pol
# 1  bablu  pol

# %% [markdown]
# csv file-comma seperated values

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dff.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# Acess the output column

# %%
dff["output"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: output, Length: 303, dtype: int64

# %% [markdown]
# How many values in output column 0 or 1

# %%
dff["output"].value_counts()
# Out:
# 1    165
# 0    138
# Name: output, dtype: int64

# %% [markdown]
# # Acessing specific row of dataframe

# %%
dff.iloc[0]
# Out:
# age          63.0
# sex           1.0
# cp            3.0
# trtbps      145.0
# chol        233.0
# fbs           1.0
# restecg       0.0
# thalachh    150.0
# exng          0.0
# oldpeak       2.3
# slp           0.0
# caa           0.0
# thall         1.0
# output        1.0
# Name: 0, dtype: float64

# %%
# acessing top 3 rows and slp column
dff.loc[[1,2,3],"slp"]
# Out:
# 1    0
# 2    2
# 3    2
# Name: slp, dtype: int64

# %%
df
# Out:
#      name    last                    email
# 0   rohan     pol     polrohan10@gmail.com
# 1   bablu     pol  poldhananjay20@gmil.com
# 2   husen  shaikh          husen@gmial.com
# 3  mahesh  jadhav         mahesh@gmail.com

# %% [markdown]
# # index : integer identifiers for row

# %%
df.set_index("email")
# Out:
#                            name    last
# email
# polrohan10@gmail.com      rohan     pol
# poldhananjay20@gmil.com   bablu     pol
# husen@gmial.com           husen  shaikh
# mahesh@gmail.com         mahesh  jadhav

# %%
# our data frame does not allow us to change
#because pandas does not allow such operations 
df
# Out:
#      name    last                    email
# 0   rohan     pol     polrohan10@gmail.com
# 1   bablu     pol  poldhananjay20@gmil.com
# 2   husen  shaikh          husen@gmial.com
# 3  mahesh  jadhav         mahesh@gmail.com

# %%
data=df.set_index("email")

# %%
data
# Out:
#                            name    last
# email
# polrohan10@gmail.com      rohan     pol
# poldhananjay20@gmil.com   bablu     pol
# husen@gmial.com           husen  shaikh
# mahesh@gmail.com         mahesh  jadhav

# %%
df.set_index("email",inplace=True)

# %%
df
# Out:
#                            name    last
# email
# polrohan10@gmail.com      rohan     pol
# poldhananjay20@gmil.com   bablu     pol
# husen@gmial.com           husen  shaikh
# mahesh@gmail.com         mahesh  jadhav

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                      email    name    last
# 0     polrohan10@gmail.com   rohan     pol
# 1  poldhananjay20@gmil.com   bablu     pol
# 2          husen@gmial.com   husen  shaikh
# 3         mahesh@gmail.com  mahesh  jadhav

# %%
pd.set_option('display.max_rows',61)

# %%
df
# Out:
#                      email    name    last
# 0     polrohan10@gmail.com   rohan     pol
# 1  poldhananjay20@gmil.com   bablu     pol
# 2          husen@gmial.com   husen  shaikh
# 3         mahesh@gmail.com  mahesh  jadhav

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
pd.set_option('display.max_rows',78)

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dff.set_index('age',inplace=True)

# %%
dff
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 57     0   0     140   241    0        1       123     1      0.2    1    0
# 45     1   3     110   264    0        1       132     0      1.2    1    0
# 68     1   0     144   193    1        1       141     0      3.4    1    2
# 57     1   0     130   131    0        1       115     1      1.2    1    1
# 57     0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# age
# 63       1       1
# ...

# %%
dff.reset_index(inplace=True)

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dfff=pd.read_csv("heart.csv",index_col="age")

# %%
dfff
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 57     0   0     140   241    0        1       123     1      0.2    1    0
# 45     1   3     110   264    0        1       132     0      1.2    1    0
# 68     1   0     144   193    1        1       141     0      3.4    1    2
# 57     1   0     130   131    0        1       115     1      1.2    1    1
# 57     0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# age
# 63       1       1
# ...

# %%
dfff.sort_index(True)
# Out:
# C:\Users\polro\AppData\Local\Temp\ipykernel_15604\3250351696.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.sort_index will be keyword-only.
#   dfff.sort_index(True)
#      caa  chol  cp  exng  fbs  oldpeak  output  restecg  sex  slp  thalachh  \
# age
# 63     0   233   3     0    1      2.3       1        0    1    0       150
# 37     0   250   2     0    0      3.5       1        1    1    0       187
# 41     0   204   1     0    0      1.4       1        0    0    2       172
# 56     0   236   1     0    0      0.8       1        1    1    2       178
# 57     0   354   0     1    0      0.6       1        1    0    2       163
# ..   ...   ...  ..   ...  ...      ...     ...      ...  ...  ...       ...
# 57     0   241   0     1    0      0.2       0        1    0    1       123
# 45     0   264   3     0    0      1.2       0        1    1    1       132
# 68     2   193   0     0    1      3.4       0        1    1    1       141
# ...

# %% [markdown]
# # Filtering

# %%
people
# Out:
# {'name': ['rohan', 'bablu', 'husen', 'mahesh'],
#  'last': ['pol', 'pol', 'shaikh', 'jadhav'],
#  'email': ['polrohan10@gmail.com',
#   'poldhananjay20@gmil.com',
#   'husen@gmial.com',
#   'mahesh@gmail.com']}

# %%
dffff=pd.DataFrame(people)

# %%
dffff
# Out:
#      name    last                    email
# 0   rohan     pol     polrohan10@gmail.com
# 1   bablu     pol  poldhananjay20@gmil.com
# 2   husen  shaikh          husen@gmial.com
# 3  mahesh  jadhav         mahesh@gmail.com

# %%
fil=(dffff["last"]=="pol")

# %%
fil
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# Name: last, dtype: bool

# %%
dffff.loc[fil]
# Out:
#     name last                    email
# 0  rohan  pol     polrohan10@gmail.com
# 1  bablu  pol  poldhananjay20@gmil.com

# %%
dffff.loc[fil,["last","name"]]
# Out:
#   last   name
# 0  pol  rohan
# 1  pol  bablu

# %% [markdown]
# # and ,or filtering in pandas filter

# %% [markdown]
# # and-&

# %% [markdown]
# # or-|

# %%
# and
fil=((dffff["last"]=="pol")&(dffff["name"]=="rohan"))

# %%
fil
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
dffff.loc[fil]
# Out:
#     name last                 email
# 0  rohan  pol  polrohan10@gmail.com

# %%
dffff.loc[fil,"name"]
# Out:
# 0    rohan
# Name: name, dtype: object

# %%
# or

# %%
filte=((dffff["last"]=="pol")|(dffff["name"]=="rohan"))

# %%
filte
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
dffff.loc[filte]
# Out:
#     name last                    email
# 0  rohan  pol     polrohan10@gmail.com
# 1  bablu  pol  poldhananjay20@gmil.com

# %%
dffff.loc[filte,["name","email"]]
# Out:
#     name                    email
# 0  rohan     polrohan10@gmail.com
# 1  bablu  poldhananjay20@gmil.com

# %%
# not- ~
dffff.loc[~fil]
# Out:
#      name    last                    email
# 1   bablu     pol  poldhananjay20@gmil.com
# 2   husen  shaikh          husen@gmial.com
# 3  mahesh  jadhav         mahesh@gmail.com

# %%
dff
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
fil=(dff["age"]>53)

# %%
dff.loc[fil,"age"]
# Out:
# 0      63
# 3      56
# 4      57
# 5      57
# 6      56
#        ..
# 297    59
# 298    57
# 300    68
# 301    57
# 302    57
# Name: age, Length: 175, dtype: int64

# %%
dff.loc[fil]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# 5     57    1   0     140   192    0        1       148     0      0.4    1
# 6     56    0   1     140   294    0        0       153     0      1.3    1
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 297   59    1   0     164   176    1        0        90     0      1.0    1
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
dff.value_counts("age")
# Out:
# age
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 51    12
# 62    11
# 60    11
# 44    11
# 56    11
# 41    10
# 64    10
# 63     9
# 67     9
# 65     8
# 55     8
# 61     8
# 53     8
# 45     8
# 43     8
# 42     8
# 50     7
# 66     7
# 48     7
# 46     7
# 49     5
# 47     5
# 70     4
# 39     4
# 68     4
# 35     4
# 69     3
# 40     3
# 38     3
# 71     3
# 37     2
# 34     2
# 76     1
# 29     1
# 74     1
# 77     1
# dtype: int64

# %%
fil=((dff["age"]==58)|(dff["age"]==57))

# %%
dff.loc[fil]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# 5     57    1   0     140   192    0        1       148     0      0.4    1
# 9     57    1   2     150   168    0        1       174     0      1.6    2
# 14    58    0   3     150   283    1        0       162     0      1.0    2
# 16    58    0   2     120   340    0        1       172     0      0.0    2
# 59    57    0   0     128   303    0        0       159     0      0.0    2
# 64    58    1   2     140   211    1        0       165     0      0.0    2
# 79    58    1   2     105   240    0        0       154     1      0.6    1
# 89    58    0   0     100   248    0        0       122     0      1.0    1
# 91    57    1   0     132   207    0        1       168     1      0.0    2
# 111   57    1   2     150   126    1        1       173     0      0.2    2
# ...

# %%
people
# Out:
# {'name': ['rohan', 'bablu', 'husen', 'mahesh'],
#  'last': ['pol', 'pol', 'shaikh', 'jadhav'],
#  'email': ['polrohan10@gmail.com',
#   'poldhananjay20@gmil.com',
#   'husen@gmial.com',
#   'mahesh@gmail.com']}

# %%
df
# Out:
#                      email    name    last
# 0     polrohan10@gmail.com   rohan     pol
# 1  poldhananjay20@gmil.com   bablu     pol
# 2          husen@gmial.com   husen  shaikh
# 3         mahesh@gmail.com  mahesh  jadhav

# %%
df.columns
# Out:
# Index(['email', 'name', 'last'], dtype='object')

# %% [markdown]
# # updating the columns

# %%
df.columns=["Email_","Name_","last_"]

# %%
df
# Out:
#                     Email_   Name_   last_
# 0     polrohan10@gmail.com   rohan     pol
# 1  poldhananjay20@gmil.com   bablu     pol
# 2          husen@gmial.com   husen  shaikh
# 3         mahesh@gmail.com  mahesh  jadhav

# %%
    # if we change the specific column that time use rename method

# %%
df.rename(columns={"Email_":"email"})
# Out:
#                      email   Name_   last_
# 0     polrohan10@gmail.com   rohan     pol
# 1  poldhananjay20@gmil.com   bablu     pol
# 2          husen@gmial.com   husen  shaikh
# 3         mahesh@gmail.com  mahesh  jadhav

# %%
df.rename(columns={"email":"email.com","Name_":"first name"},inplace=True)

# %%
df
# Out:
#                     Email_ first name   last_
# 0     polrohan10@gmail.com      rohan     pol
# 1  poldhananjay20@gmil.com      bablu     pol
# 2          husen@gmial.com      husen  shaikh
# 3         mahesh@gmail.com     mahesh  jadhav

# %%
# updating the specific row
df.loc[3]=["suchit","niranjan","suchit@123"]

# %%
df
# Out:
#                     Email_ first name       last_
# 0     polrohan10@gmail.com      rohan         pol
# 1  poldhananjay20@gmil.com      bablu         pol
# 2          husen@gmial.com      husen      shaikh
# 3                   suchit   niranjan  suchit@123

# %%
df.loc[3,["Email_","last_"]]=["suchit@123","suchit"]

# %%
df
# Out:
#                     Email_ first name   last_
# 0     polrohan10@gmail.com      rohan     pol
# 1  poldhananjay20@gmil.com      bablu     pol
# 2          husen@gmial.com      husen  shaikh
# 3               suchit@123   niranjan  suchit

# %%
# insert,add,delete

# %%
people
# Out:
# {'name': ['rohan', 'bablu', 'husen', 'mahesh'],
#  'last': ['pol', 'pol', 'shaikh', 'jadhav'],
#  'email': ['polrohan10@gmail.com',
#   'poldhananjay20@gmil.com',
#   'husen@gmial.com',
#   'mahesh@gmail.com']}

# %%
df
# Out:
#                     Email_ first name   last_
# 0     polrohan10@gmail.com      rohan     pol
# 1  poldhananjay20@gmil.com      bablu     pol
# 2          husen@gmial.com      husen  shaikh
# 3               suchit@123   niranjan  suchit

# %%
df["full_name"]=df["first name"]+" "+df["last_"]

# %%
df
# Out:
#                     Email_ first name   last_  rohan pol  bablu pol  \
# 0     polrohan10@gmail.com      rohan     pol  rohan pol  bablu pol
# 1  poldhananjay20@gmil.com      bablu     pol  rohan pol  bablu pol
# 2          husen@gmial.com      husen  shaikh  rohan pol  bablu pol
# 3               suchit@123   niranjan  suchit  rohan pol  bablu pol
#
#    husen shaikh  niranjan suchit        full_name
# 0  husen shaikh  niranjan suchit        rohan pol
# 1  husen shaikh  niranjan suchit        bablu pol
# 2  husen shaikh  niranjan suchit     husen shaikh
# 3  husen shaikh  niranjan suchit  niranjan suchit

# %%
df.drop(columns=["rohan pol","bablu pol","husen shaikh","niranjan suchit"],inplace=True)

# %%
df
# Out:
#                     Email_ first name   last_        full_name
# 0     polrohan10@gmail.com      rohan     pol        rohan pol
# 1  poldhananjay20@gmil.com      bablu     pol        bablu pol
# 2          husen@gmial.com      husen  shaikh     husen shaikh
# 3               suchit@123   niranjan  suchit  niranjan suchit

# %%
df["full_name"].str.split(" ")
# Out:
# 0          [rohan, pol]
# 1          [bablu, pol]
# 2       [husen, shaikh]
# 3    [niranjan, suchit]
# Name: full_name, dtype: object

# %%
df["full_name"].str.split(" ",expand=True)
# Out:
#           0       1
# 0     rohan     pol
# 1     bablu     pol
# 2     husen  shaikh
# 3  niranjan  suchit

# %%
df[["first name","last"]]=df["full_name"].str.split(" ",expand=True)

# %%
df
# Out:
#                     Email_ first name   last_        full_name    last
# 0     polrohan10@gmail.com      rohan     pol        rohan pol     pol
# 1  poldhananjay20@gmil.com      bablu     pol        bablu pol     pol
# 2          husen@gmial.com      husen  shaikh     husen shaikh  shaikh
# 3               suchit@123   niranjan  suchit  niranjan suchit  suchit

# %%
df=df.append({"first name":"diksha"},ignore_index=True)
# Out:
# C:\Users\polro\AppData\Local\Temp\ipykernel_15604\2534103082.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append({"first name":"diksha"},ignore_index=True)

# %%
df
# Out:
#                     Email_ first name   last_        full_name    last
# 0     polrohan10@gmail.com      rohan     pol        rohan pol     pol
# 1  poldhananjay20@gmil.com      bablu     pol        bablu pol     pol
# 2          husen@gmial.com      husen  shaikh     husen shaikh  shaikh
# 3               suchit@123   niranjan  suchit  niranjan suchit  suchit
# 4                      NaN     diksha     NaN              NaN     NaN
# 5                      NaN     diksha     NaN              NaN     NaN

# %%
df.drop(index=3,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15604\2753614043.py in <module>
# ----> 1 df.drop(index=3,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...
